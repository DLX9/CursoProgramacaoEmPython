# %%
from logging import exception
# erro de str em unput de int
# digitar somente numeros
#Variavel if else
cond = True

#Estrutura repetição
while cond == True :
  try:
    #input leitura
    n1 = int(input("Number: "))
    print("Deu bom, seu némero é" , n1)
    cond = False
  except:
    print("Deu ruim")
