# %%
#Atividade 1

idd = int(input("Digite sua idade: "))

if(idd >= 12) and (idd <= 65):
  print("Você pode andar na montanha russa")
else:
  print("Sua idade é inadequada para andar de montanha russa")
# Out:
# Digite sua idade: 66
# Sua idade é inadequada para andar de montanha russa

# %%
#Atividade 2
user = "asd@gmail.com"
password = "asd"

usuario = input("Insira seu email... ")
senha = input("Insira sua senha... ")

if (user == usuario) and (password == senha):
  print(f"Bem vindo, {user}")
else:
  print("Tente novamente")
# Out:
# Insira seu email... asd@gmail.com
# Insira sua senha... asd
# Bem vindo, asd@gmail.com

# %%
#Atividade 3
valor = float(input("Insira o valor da compra: "))
anos = int(input("Insira a quantos anos você compra nessa loja: "))

if (valor >= 100) or (anos >= 5):
  print("Desconto habilitado")
else:
  print("Desconto desabilitado")
# Out:
# Insira o valor da compra: 99
# Insira a quantos anos você compra nessa loja: 5
# Desconto habilitado
