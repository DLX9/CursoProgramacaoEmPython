# %%
x = 5
y = 10
z = 3
saida = (x < y) and (z > y)
print(saida)
# Out:
# False

# %%
#variaveis de entrada
x = "administrador"
y = "1234"

#Entrada de login de usuário
usuario = input("Insira o nome de usuário: ")
senha = input("Insira a senha: ")

#Processamento login
if (usuario == x) and (senha == y):
  print(f"Bem vindo a sessão de usuário {usuario}")
else:
  print("Credenciais incorretas")
# Out:
# Insira o nome de usuário: Leonardo
# Insira a senha: 1234
# Bem vindo a sessão de usuário Leonardo
