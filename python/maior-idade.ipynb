# %%
#Variaveis do sistema
nome = "Nome padrão"
idade = "0"

#Resgata os dados do usuário
nome = input("Insira seu nome: ")
idade = int(input("Insira sua idade: "))

if(idade < 18):
  print(f"Olá, {nome}")
  print(f"Você ainda é menor de idade, não pode entrar.")
else:
  print(f"Olá, {nome}")
  print(f"Você já é maior de idade, seja bem vindo.")
# Out:
# Insira seu nome: sad
# Insira sua idade: 18
# Olá, sad
# Você já é maior de idade
