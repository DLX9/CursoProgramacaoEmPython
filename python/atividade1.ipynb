# %%
from re import escape
#Variaveis do algoritimo
numero = 0

#Mensagem de bem vindo
print("Bem vindo(a) ao sistema onde descobrimos se o número impar ou par")

#Recupera o número do usuário
numero = int(input("Por favor digite seu número: "))

#Sisteam condicional que verifica se o número é possitivo negativo ou 0
if (numero % 2 == 0):
    print("É um número par")
else:
    print("O número é impar")

# %%
from re import escape
#Mensagem de bem vindo
print("Bem vindo(a) ao sistema onde descobrimos se o número é positivo, negativo ou 0")

#Recupera o número do usuário
numero = int(input("Por favor digite seu número: "))

#Sisteam condicional que verifica se o número é possitivo negativo ou 0
if(numero < 0):
    print("É um número negativo")
elif(numero > 0):
    print("É um número positivo")
else:
    print("O número é zero")
