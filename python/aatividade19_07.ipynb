# %%
#Vetor com 5 valores
lista = [1, 2, 3, 4, 5]

#Exibe em um laço de repetição os itens da lista
for item in lista:
  print(item)

# %%
#Vetor com nome dos doces
doces = ["Bala", "Pirulito", "Pudim", "Bolo", "Bombom", "Chocolate", "Palha italiana", "Jujaba", "Donout", "Caramelo"]

for item in doces:
  print(item)

# %%
#variavel de controle
controle = 0

while (controle == 0):
  print("1 - Cadastrar")
  print("2 - Editar")
  print("3 - Excluir")

  controle = int(input("Digite 0 para voltar ao menu: "))

# %% [markdown]
# Desafios da aula

# %%
#Desafio 1

num = int(input("Digite seu numero: "))

print(num)

while num > 0:
  num -= 1
  print(num)

# %%
#Desafio 2
user = "asd@gmail.com"
password = "asd"
t = 0
n = 2
while t < 3:
  usuario = input("Digite seu email: ")
  senha = input("Digite sua senha: ")
  if(user == usuario) and (password == senha):
    print("Seja bem vindo")
    t += 4
  elif(n > 0):
    print(f"Credenciais incorretas, você tem mais {n} tentativas")
    n -= 1
    t += 1
  else:
    print("Você foi bloqueado por 60 minutos")
    t += 4

# %%
#Desafio 3
print("Exemplo: quero que calcule todos os números pares de (base) até (maximo)")
n1 = int(input("Digite a base da soma: "))
n2 = int(input("Digite qual o número maximo: "))
r = 0

while n1 <= n2:
  if(n1%2 == 0):
    r += n1
    n1 += 1
  else:
    n1 += 1

print(f"A soma de todos os numeros pares entre: {r}")

# %%
#Desafio 4
print("Exemplo: quero que calcule todos os números primos de (base) até (maximo)")
n1 = int(input("Digite a base da soma: "))
n2 = int(input("Digite qual o número maximo: "))
r = 0

while n1 <= n2:
  if (n1 == 0) or (n1 == 1):
    n1 += 1
  elif (n1%2 == 0 and n1 != 2) or (n1%3 == 0 and n1 != 3) or (n1%5 == 0 and n1 != 5) or (n1%7 == 0 and n1 != 7) or (n1%11 == 0 and n1 != 11):
    n1 += 1
  else:
    r += n1
    n1 += 1


print(f"A soma de todos os numeros primos é: {r}")
# Out:
# Exemplo: quero que calcule todos os números primos de (base) até (maximo)
# Digite a base da soma: 0
# Digite qual o número maximo: 10
# A soma de todos os numeros primos é: 17

# %%
#Desafio 5

a = 1
b = 1
print("Lembre que a cada número que inserir você será multiplicado por 3")
x = int(input("Insira quantos numeros da sequencia de fibonate você quer ver: "))

while x > 0:
  print(a)
  print(b)
  c = a + b
  print(c)
  a = c + b
  b = a + c
  x -= 1
# Out:
# Lembre que a cada número que inserir você será multiplicado por 3
# Insira quantos numeros da sequencia de fibonate você quer ver: 3
# 1
# 1
# 2
# 8
# 34

# %%
#Desafio final

print("Seja bem vindo ao sistema de contabilizar notas:")
qnt = int(input("Insira quantos alunos você tem: "))
p = qnt
nomes = []
media = []
dic = []
n1 = 0
n2 = 0
n3 = 0
n4 = 0

x = 0
while qnt > 0:

  print("------------")
  nomes.append(input("Intisa o primeiro nome: "))
  dic.append(input("Intisa a diciplina: "))
  n1 = int((input("Intisa sua primeira nota: ")))
  n2 = int((input("Intisa sua segunda nota: ")))
  n3 = int((input("Intisa sua terceira nota: ")))
  n4 = int((input("Intisa sua quarta nota: ")))
  media.append((n1 + n2 + n3 + n4)/4)
  print("")
  qnt -= 1

x = 0
while p > 0:
  print("------------")
  print(nomes[x])
  print(dic[x])
  print(media[x])
  if (media[x] >= 7):
    print("FOI APROVADO")
  elif(media[x] >= 5 and media[x] < 7):
    print("RECUPERAÇÃO")
  else:
    print("FOI REPROVADO")
  print("")
  x += 1
  p -= 1
# Out:
# Seja bem vindo ao sistema de contabilizar notas:
# Insira quantos alunos você tem: 1
# ------------
# Intisa o primeiro nome: Leonardo
# Intisa a diciplina: Mat
# Intisa sua primeira nota: 8
# Intisa sua segunda nota: 8
# Intisa sua terceira nota: 8
# Intisa sua quarta nota: 8
#
# ------------
# Leonardo
# Mat
# 8.0
# FOI APROVADO
